# %%
# Initialization:
import pandas as pd
from src.utils import *

df = pd.read_excel("./data/dailyraw.xls", skiprows=2)
df = cleanup_df(df)
lpp = get_lpp(df)
columbia = get_all_columbia(df)

approvals = pd.read_excel("./data/approvals.xlsx")
approvals = normalize_approvals(approvals)

# %%
# Finding LPP data mistmatch in regard of the approval sheet:
discrepencies = find_lpp_discrepencies(lpp, approvals)
print(discrepencies)
print(len(lpp), lpp)

lpp2 = lpp[[lpp.DEST, lpp.STYLE]]

# %%
# Validating columbia destinations:
columbia
lpp
