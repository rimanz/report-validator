# %%
# Initialize
# %pip install xlrd openpyxl pyexcel pyexcel-xls
import pandas as pd
import pyexcel as pe
from src.utils import *

df = pd.read_excel("./data/dailyraw.xls", skiprows=2)
df = cleanup_df(df)
lpp = get_lpp(df)
columbia = get_all_columbia(df)
non_columbia = get_non_columbia(df)

approvals = pd.read_excel("./data/approvals.xlsx")
df_approvals = normalize_approvals(approvals)
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Find LPP data mistmatch with approval sheet
discrepencies = find_lpp_discrepencies(lpp, df_approvals)
discrepencies
# Out:
# ==> No discrepancies found between approvals and report!

# %%
# Find CBM discrepencies with MSMT (Columbia and their IDR Consighees are excluded)
cbm_mismatches = get_cbm_mismatch(non_columbia)
cbm_mismatches if len(cbm_mismatches) > 0 else print("==>", "No CBM mismatches found!")
# Out:
# ==> No CBM mismatches found!

# %%
# Generate a LPP upload file using approved data
upload = generate_lpp_upload_file(approvals)
upload.head(1)
# Out:
#         S/O CONSIGNEE SHIPPER  PKGS PKG UNIT   QTY QTY UNIT   CBM  CGO WT  \
# 0  11499470   LPP S.A       .    60   CARTON  2000      PCS  5.28  1260.0
#
#          PO  STYLE        ITEM DIV CAT    WHS
# 0  11499470  382HB  DC1 HALL 3          HOUSE
